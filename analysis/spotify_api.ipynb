# %% [markdown]
# ## Imports

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from sqlalchemy import create_engine
import pandas as pd
import os 
from dotenv import load_dotenv

# %% [markdown]
# ## Credentials and Connections

# %%
load_dotenv()

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id=os.getenv("SPOTIFY_CLIENT_ID"),
    client_secret=os.getenv("SPOTIFY_CLIENT_SECRET")
))

engine = create_engine(
    f"postgresql://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}"
    f"@{os.getenv('DB_HOST')}/{os.getenv('DB_NAME')}"
)

# %% [markdown]
# ## SQL Queries

# %%
contestants = pd.read_sql("""
    SELECT year, country, performer, song, final_total_points
    FROM contestants
    WHERE final_total_points IS NOT NULL         
    AND year = 2021           
""", engine)

# %%
contestants
# Out:
#     year country              performer                       song  \
# 0   2021      IT               Måneskin              Zitti e buoni
# 1   2021      FR          Barbara Pravi                      Voilà
# 2   2021      CH           Gjon's Tears             Tout l'univers
# 3   2021      IS     Daði & Gagnamagnið                   10 Years
# 4   2021      UA                   Go_A                       Shum
# 5   2021      FI          Blind Channel                  Dark Side
# 6   2021      MT                Destiny                Je Me Casse
# 7   2021      LT               The Roop                 Discoteque
# 8   2021      RU                Manizha              Russian Woman
# 9   2021      GR               Stefania                 Last Dance
# 10  2021      BG               Victoria  Growing Up Is Getting Old
# 11  2021      PT        The Black Mamba         Love Is On My Side
# 12  2021      MD      Natalia Gordienko                      Sugar
# 13  2021      SE                  Tusse                     Voices
# 14  2021      RS              Hurricane                  Loco Loco
# 15  2021      CY        Elena Tsagrinou                  El Diablo
# 16  2021      IL             Eden Alene                Set Me Free
# 17  2021      NO                    TIX               Fallen Angel
# 18  2021      BE           Hooverphonic            The Wrong Place
# 19  2021      AZ                 Efendi                  Mata Hari
# 20  2021      AL      Anxhela Peristeri                      Karma
# 21  2021      SM  Senhit feat. Flo Rida                 Adrenalina
# 22  2021      NL         Jeangu Macrooy         Birth Of A New Age
# 23  2021      ES             Blas Cantó             Voy A Quedarme
# 24  2021      DE                Jendrik          I Don't Feel Hate
# 25  2021      GB           James Newman                     Embers
#
#    final_total_points
# 0                 524
# 1                 499
# 2                 432
# 3                 378
# 4                 364
# 5                 301
# 6                 255
# 7                 220
# 8                 204
# 9                 170
# 10                170
# 11                153
# 12                115
# 13                109
# 14                102
# 15                 94
# 16                 93
# 17                 75
# 18                 74
# 19                 65
# 20                 57
# 21                 50
# 22                 11
# 23                  6
# 24                  3
# 25                  0
